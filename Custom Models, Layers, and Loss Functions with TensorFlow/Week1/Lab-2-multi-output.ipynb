# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 926us/sample - loss: 230.1866 - y1_output_loss: 105.5646 - y2_output_loss: 122.7144 - y1_output_root_mean_squared_error: 10.3144 - y2_output_root_mean_squared_error: 11.1266 - val_loss: 38.9962 - val_y1_output_loss: 16.8409 - val_y2_output_loss: 21.0191 - val_y1_output_root_mean_squared_error: 4.1641 - val_y2_output_root_mean_squared_error: 4.6537
# Epoch 2/500
# 614/614 [==============================] - 0s 140us/sample - loss: 30.8204 - y1_output_loss: 12.3914 - y2_output_loss: 18.4475 - y1_output_root_mean_squared_error: 3.5028 - y2_output_root_mean_squared_error: 4.3070 - val_loss: 25.3739 - val_y1_output_loss: 10.7820 - val_y2_output_loss: 14.1460 - val_y1_output_root_mean_squared_error: 3.3175 - val_y2_output_root_mean_squared_error: 3.7905
# Epoch 3/500
# 614/614 [==============================] - 0s 131us/sample - loss: 23.1115 - y1_output_loss: 9.3204 - y2_output_loss: 13.8828 - y1_output_root_mean_squared_error: 3.0559 - y2_output_root_mean_squared_error: 3.7112 - val_loss: 23.7585 - val_y1_output_loss: 9.8537 - val_y2_output_loss: 13.5969 - val_y1_output_root_mean_squared_error: 3.1586 - val_y2_output_root_mean_squared_error: 3.7124
# Epoch 4/500
# 614/614 [==============================] - 0s 130us/sample - loss: 24.0656 - y1_output_loss: 9.0629 - y2_output_loss: 14.9043 - y1_output_root_mean_squared_error: 3.0107 - y2_output_root_mean_squared_error: 3.8732 - val_loss: 24.9825 - val_y1_output_loss: 11.6042 - val_y2_output_loss: 12.8110 - val_y1_output_root_mean_squared_error: 3.4463 - val_y2_output_root_mean_squared_error: 3.6202
# Epoch 5/500
# 614/614 [==============================] - 0s 134us/sample - loss: 24.1090 - y1_output_loss: 9.0803 - y2_output_loss: 14.8342 - y1_output_root_mean_squared_error: 3.0251 - y2_output_root_mean_squared_error: 3.8676 - val_loss: 21.7066 - val_y1_output_loss: 9.0474 - val_y2_output_loss: 12.0883 - val_y1_output_root_mean_squared_error: 3.0482 - val_y2_output_root_mean_squared_error: 3.5235
# Epoch 6/500
# 614/614 [==============================] - 0s 129us/sample - loss: 20.9218 - y1_output_loss: 8.5927 - y2_output_loss: 12.2126 - y1_output_root_mean_squared_error: 2.9383 - y2_output_root_mean_squared_error: 3.5054 - val_loss: 23.3535 - val_y1_output_loss: 9.7433 - val_y2_output_loss: 13.3650 - val_y1_output_root_mean_squared_error: 3.1423 - val_y2_output_root_mean_squared_error: 3.6714
# Epoch 7/500
# 614/614 [==============================] - 0s 129us/sample - loss: 21.3086 - y1_output_loss: 8.3886 - y2_output_loss: 12.7720 - y1_output_root_mean_squared_error: 2.9053 - y2_output_root_mean_squared_error: 3.5872 - val_loss: 21.3162 - val_y1_output_loss: 8.8156 - val_y2_output_loss: 12.2332 - val_y1_output_root_mean_squared_error: 2.9875 - val_y2_output_root_mean_squared_error: 3.5201
# Epoch 8/500
# 614/614 [==============================] - 0s 131us/sample - loss: 21.7271 - y1_output_loss: 8.4973 - y2_output_loss: 13.0693 - y1_output_root_mean_squared_error: 2.9258 - y2_output_root_mean_squared_error: 3.6286 - val_loss: 21.5019 - val_y1_output_loss: 9.2527 - val_y2_output_loss: 12.0755 - val_y1_output_root_mean_squared_error: 3.0537 - val_y2_output_root_mean_squared_error: 3.4895
# Epoch 9/500
# 614/614 [==============================] - 0s 132us/sample - loss: 21.0760 - y1_output_loss: 8.0607 - y2_output_loss: 12.8886 - y1_output_root_mean_squared_error: 2.8492 - y2_output_root_mean_squared_error: 3.5997 - val_loss: 21.9290 - val_y1_output_loss: 9.5484 - val_y2_output_loss: 12.2806 - val_y1_output_root_mean_squared_error: 3.0980 - val_y2_output_root_mean_squared_error: 3.5116
# Epoch 10/500
# 614/614 [==============================] - 0s 129us/sample - loss: 21.8867 - y1_output_loss: 8.1947 - y2_output_loss: 14.3695 - y1_output_root_mean_squared_error: 2.8551 - y2_output_root_mean_squared_error: 3.7061 - val_loss: 60.7529 - val_y1_output_loss: 17.1873 - val_y2_output_loss: 42.4802 - val_y1_output_root_mean_squared_error: 4.2008 - val_y2_output_root_mean_squared_error: 6.5655
# Epoch 11/500
# 614/614 [==============================] - 0s 129us/sample - loss: 23.3523 - y1_output_loss: 8.5203 - y2_output_loss: 14.7376 - y1_output_root_mean_squared_error: 2.9229 - y2_output_root_mean_squared_error: 3.8482 - val_loss: 34.9822 - val_y1_output_loss: 13.0586 - val_y2_output_loss: 21.8917 - val_y1_output_root_mean_squared_error: 3.6017 - val_y2_output_root_mean_squared_error: 4.6914
# Epoch 12/500
# 614/614 [==============================] - 0s 138us/sample - loss: 20.2303 - y1_output_loss: 7.8405 - y2_output_loss: 12.2929 - y1_output_root_mean_squared_error: 2.8012 - y2_output_root_mean_squared_error: 3.5191 - val_loss: 30.2789 - val_y1_output_loss: 10.9670 - val_y2_output_loss: 19.3755 - val_y1_output_root_mean_squared_error: 3.2934 - val_y2_output_root_mean_squared_error: 4.4082
# Epoch 13/500
# 614/614 [==============================] - 0s 138us/sample - loss: 20.2169 - y1_output_loss: 7.7146 - y2_output_loss: 12.3425 - y1_output_root_mean_squared_error: 2.7856 - y2_output_root_mean_squared_error: 3.5295 - val_loss: 21.0686 - val_y1_output_loss: 9.5203 - val_y2_output_loss: 11.0881 - val_y1_output_root_mean_squared_error: 3.1215 - val_y2_output_root_mean_squared_error: 3.3652
# Epoch 14/500
# 614/614 [==============================] - 0s 135us/sample - loss: 18.1431 - y1_output_loss: 7.0615 - y2_output_loss: 11.3883 - y1_output_root_mean_squared_error: 2.6422 - y2_output_root_mean_squared_error: 3.3409 - val_loss: 28.7133 - val_y1_output_loss: 9.1039 - val_y2_output_loss: 19.3449 - val_y1_output_root_mean_squared_error: 3.0239 - val_y2_output_root_mean_squared_error: 4.4238
# Epoch 15/500
# 614/614 [==============================] - 0s 135us/sample - loss: 21.7970 - y1_output_loss: 8.0476 - y2_output_loss: 13.5623 - y1_output_root_mean_squared_error: 2.8482 - y2_output_root_mean_squared_error: 3.6993 - val_loss: 19.7296 - val_y1_output_loss: 8.6584 - val_y2_output_loss: 10.6683 - val_y1_output_root_mean_squared_error: 2.9715 - val_y2_output_root_mean_squared_error: 3.3015
# Epoch 16/500
# 614/614 [==============================] - 0s 138us/sample - loss: 17.5079 - y1_output_loss: 6.8433 - y2_output_loss: 10.5623 - y1_output_root_mean_squared_error: 2.6255 - y2_output_root_mean_squared_error: 3.2580 - val_loss: 19.2735 - val_y1_output_loss: 7.8991 - val_y2_output_loss: 10.9364 - val_y1_output_root_mean_squared_error: 2.8400 - val_y2_output_root_mean_squared_error: 3.3478
# Epoch 17/500
# 614/614 [==============================] - 0s 128us/sample - loss: 16.8978 - y1_output_loss: 6.6628 - y2_output_loss: 10.3214 - y1_output_root_mean_squared_error: 2.5703 - y2_output_root_mean_squared_error: 3.2080 - val_loss: 35.8315 - val_y1_output_loss: 10.1409 - val_y2_output_loss: 25.4145 - val_y1_output_root_mean_squared_error: 3.1961 - val_y2_output_root_mean_squared_error: 5.0613
# Epoch 18/500
# 614/614 [==============================] - 0s 132us/sample - loss: 15.2172 - y1_output_loss: 6.2540 - y2_output_loss: 9.1618 - y1_output_root_mean_squared_error: 2.4927 - y2_output_root_mean_squared_error: 3.0006 - val_loss: 34.4690 - val_y1_output_loss: 8.9945 - val_y2_output_loss: 25.5518 - val_y1_output_root_mean_squared_error: 2.9805 - val_y2_output_root_mean_squared_error: 5.0582
# Epoch 19/500
# 614/614 [==============================] - 0s 138us/sample - loss: 18.0174 - y1_output_loss: 6.8621 - y2_output_loss: 11.5310 - y1_output_root_mean_squared_error: 2.6133 - y2_output_root_mean_squared_error: 3.3449 - val_loss: 120.4636 - val_y1_output_loss: 22.1400 - val_y2_output_loss: 95.6472 - val_y1_output_root_mean_squared_error: 4.7824 - val_y2_output_root_mean_squared_error: 9.8789
# Epoch 20/500
# 614/614 [==============================] - 0s 139us/sample - loss: 18.9313 - y1_output_loss: 6.5339 - y2_output_loss: 12.2771 - y1_output_root_mean_squared_error: 2.5592 - y2_output_root_mean_squared_error: 3.5188 - val_loss: 17.8854 - val_y1_output_loss: 8.7306 - val_y2_output_loss: 8.7465 - val_y1_output_root_mean_squared_error: 2.9920 - val_y2_output_root_mean_squared_error: 2.9889
# Epoch 21/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.4677 - y1_output_loss: 5.7833 - y2_output_loss: 8.7537 - y1_output_root_mean_squared_error: 2.4082 - y2_output_root_mean_squared_error: 2.9442 - val_loss: 22.1068 - val_y1_output_loss: 8.7145 - val_y2_output_loss: 12.9163 - val_y1_output_root_mean_squared_error: 2.9820 - val_y2_output_root_mean_squared_error: 3.6352
# Epoch 22/500
# 614/614 [==============================] - 0s 134us/sample - loss: 19.0007 - y1_output_loss: 6.5723 - y2_output_loss: 12.4112 - y1_output_root_mean_squared_error: 2.5667 - y2_output_root_mean_squared_error: 3.5232 - val_loss: 15.8280 - val_y1_output_loss: 6.5750 - val_y2_output_loss: 9.2732 - val_y1_output_root_mean_squared_error: 2.5549 - val_y2_output_root_mean_squared_error: 3.0496
# Epoch 23/500
# 614/614 [==============================] - 0s 145us/sample - loss: 13.3529 - y1_output_loss: 5.3318 - y2_output_loss: 8.0167 - y1_output_root_mean_squared_error: 2.3163 - y2_output_root_mean_squared_error: 2.8262 - val_loss: 33.4081 - val_y1_output_loss: 8.9382 - val_y2_output_loss: 23.5600 - val_y1_output_root_mean_squared_error: 3.0315 - val_y2_output_root_mean_squared_error: 4.9212
# Epoch 24/500
# 614/614 [==============================] - 0s 141us/sample - loss: 15.8416 - y1_output_loss: 5.8234 - y2_output_loss: 9.8762 - y1_output_root_mean_squared_error: 2.4233 - y2_output_root_mean_squared_error: 3.1574 - val_loss: 14.5294 - val_y1_output_loss: 5.9278 - val_y2_output_loss: 8.3332 - val_y1_output_root_mean_squared_error: 2.4583 - val_y2_output_root_mean_squared_error: 2.9131
# Epoch 25/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.7333 - y1_output_loss: 5.4336 - y2_output_loss: 9.1792 - y1_output_root_mean_squared_error: 2.3421 - y2_output_root_mean_squared_error: 3.0410 - val_loss: 13.2158 - val_y1_output_loss: 5.6088 - val_y2_output_loss: 7.4642 - val_y1_output_root_mean_squared_error: 2.3659 - val_y2_output_root_mean_squared_error: 2.7602
# Epoch 26/500
# 614/614 [==============================] - 0s 144us/sample - loss: 12.8740 - y1_output_loss: 4.7952 - y2_output_loss: 8.2123 - y1_output_root_mean_squared_error: 2.1924 - y2_output_root_mean_squared_error: 2.8403 - val_loss: 15.0267 - val_y1_output_loss: 6.0922 - val_y2_output_loss: 8.8632 - val_y1_output_root_mean_squared_error: 2.4569 - val_y2_output_root_mean_squared_error: 2.9984
# Epoch 27/500
# 614/614 [==============================] - 0s 155us/sample - loss: 13.4798 - y1_output_loss: 4.9671 - y2_output_loss: 8.6710 - y1_output_root_mean_squared_error: 2.2326 - y2_output_root_mean_squared_error: 2.9147 - val_loss: 52.1365 - val_y1_output_loss: 12.0149 - val_y2_output_loss: 38.9866 - val_y1_output_root_mean_squared_error: 3.5158 - val_y2_output_root_mean_squared_error: 6.3068
# Epoch 28/500
# 614/614 [==============================] - 0s 164us/sample - loss: 12.7465 - y1_output_loss: 4.6263 - y2_output_loss: 8.0165 - y1_output_root_mean_squared_error: 2.1597 - y2_output_root_mean_squared_error: 2.8430 - val_loss: 11.7664 - val_y1_output_loss: 5.2589 - val_y2_output_loss: 6.5058 - val_y1_output_root_mean_squared_error: 2.2818 - val_y2_output_root_mean_squared_error: 2.5612
# Epoch 29/500
# 614/614 [==============================] - 0s 150us/sample - loss: 14.8776 - y1_output_loss: 5.2815 - y2_output_loss: 9.6882 - y1_output_root_mean_squared_error: 2.2956 - y2_output_root_mean_squared_error: 3.0997 - val_loss: 25.4006 - val_y1_output_loss: 6.3418 - val_y2_output_loss: 18.4555 - val_y1_output_root_mean_squared_error: 2.5531 - val_y2_output_root_mean_squared_error: 4.3454
# Epoch 30/500
# 614/614 [==============================] - 0s 150us/sample - loss: 11.9708 - y1_output_loss: 4.4250 - y2_output_loss: 7.4920 - y1_output_root_mean_squared_error: 2.1024 - y2_output_root_mean_squared_error: 2.7478 - val_loss: 10.7204 - val_y1_output_loss: 4.5095 - val_y2_output_loss: 6.2473 - val_y1_output_root_mean_squared_error: 2.1029 - val_y2_output_root_mean_squared_error: 2.5096
# Epoch 31/500
# 614/614 [==============================] - 0s 133us/sample - loss: 10.3744 - y1_output_loss: 4.0333 - y2_output_loss: 6.5198 - y1_output_root_mean_squared_error: 1.9965 - y2_output_root_mean_squared_error: 2.5275 - val_loss: 22.9175 - val_y1_output_loss: 6.4956 - val_y2_output_loss: 15.8595 - val_y1_output_root_mean_squared_error: 2.5769 - val_y2_output_root_mean_squared_error: 4.0345
# Epoch 32/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.1516 - y1_output_loss: 3.6480 - y2_output_loss: 6.4991 - y1_output_root_mean_squared_error: 1.9139 - y2_output_root_mean_squared_error: 2.5472 - val_loss: 22.8209 - val_y1_output_loss: 7.0909 - val_y2_output_loss: 15.1546 - val_y1_output_root_mean_squared_error: 2.6981 - val_y2_output_root_mean_squared_error: 3.9422
# Epoch 33/500
# 614/614 [==============================] - 0s 136us/sample - loss: 10.3557 - y1_output_loss: 3.8132 - y2_output_loss: 6.5530 - y1_output_root_mean_squared_error: 1.9549 - y2_output_root_mean_squared_error: 2.5562 - val_loss: 14.0294 - val_y1_output_loss: 4.4770 - val_y2_output_loss: 9.8714 - val_y1_output_root_mean_squared_error: 2.0654 - val_y2_output_root_mean_squared_error: 3.1247
# Epoch 34/500
# 614/614 [==============================] - 0s 137us/sample - loss: 10.0545 - y1_output_loss: 3.5964 - y2_output_loss: 6.3905 - y1_output_root_mean_squared_error: 1.9040 - y2_output_root_mean_squared_error: 2.5356 - val_loss: 9.3823 - val_y1_output_loss: 3.7964 - val_y2_output_loss: 5.5113 - val_y1_output_root_mean_squared_error: 1.9422 - val_y2_output_root_mean_squared_error: 2.3686
# Epoch 35/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.1484 - y1_output_loss: 3.1871 - y2_output_loss: 5.8838 - y1_output_root_mean_squared_error: 1.7933 - y2_output_root_mean_squared_error: 2.4357 - val_loss: 9.5378 - val_y1_output_loss: 3.8945 - val_y2_output_loss: 5.6680 - val_y1_output_root_mean_squared_error: 1.9564 - val_y2_output_root_mean_squared_error: 2.3896
# Epoch 36/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.1567 - y1_output_loss: 3.2630 - y2_output_loss: 5.8389 - y1_output_root_mean_squared_error: 1.8113 - y2_output_root_mean_squared_error: 2.4240 - val_loss: 10.2245 - val_y1_output_loss: 3.4263 - val_y2_output_loss: 6.8717 - val_y1_output_root_mean_squared_error: 1.8264 - val_y2_output_root_mean_squared_error: 2.6246
# Epoch 37/500
# 614/614 [==============================] - 0s 138us/sample - loss: 9.4625 - y1_output_loss: 3.3478 - y2_output_loss: 6.0407 - y1_output_root_mean_squared_error: 1.8363 - y2_output_root_mean_squared_error: 2.4679 - val_loss: 9.1314 - val_y1_output_loss: 3.6767 - val_y2_output_loss: 5.6265 - val_y1_output_root_mean_squared_error: 1.8819 - val_y2_output_root_mean_squared_error: 2.3643
# Epoch 38/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.9420 - y1_output_loss: 3.1588 - y2_output_loss: 5.7077 - y1_output_root_mean_squared_error: 1.7845 - y2_output_root_mean_squared_error: 2.3995 - val_loss: 8.3833 - val_y1_output_loss: 3.3324 - val_y2_output_loss: 4.9601 - val_y1_output_root_mean_squared_error: 1.8250 - val_y2_output_root_mean_squared_error: 2.2478
# Epoch 39/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.6159 - y1_output_loss: 2.9115 - y2_output_loss: 5.6388 - y1_output_root_mean_squared_error: 1.7130 - y2_output_root_mean_squared_error: 2.3836 - val_loss: 9.3187 - val_y1_output_loss: 4.0108 - val_y2_output_loss: 5.3592 - val_y1_output_root_mean_squared_error: 1.9857 - val_y2_output_root_mean_squared_error: 2.3186
# Epoch 40/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.8860 - y1_output_loss: 2.6249 - y2_output_loss: 5.1910 - y1_output_root_mean_squared_error: 1.6269 - y2_output_root_mean_squared_error: 2.2889 - val_loss: 9.4007 - val_y1_output_loss: 3.6735 - val_y2_output_loss: 6.1378 - val_y1_output_root_mean_squared_error: 1.8504 - val_y2_output_root_mean_squared_error: 2.4448
# Epoch 41/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.6812 - y1_output_loss: 2.7945 - y2_output_loss: 5.8571 - y1_output_root_mean_squared_error: 1.6743 - y2_output_root_mean_squared_error: 2.4245 - val_loss: 9.7973 - val_y1_output_loss: 3.8565 - val_y2_output_loss: 5.9341 - val_y1_output_root_mean_squared_error: 1.9481 - val_y2_output_root_mean_squared_error: 2.4500
# Epoch 42/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.2225 - y1_output_loss: 2.9282 - y2_output_loss: 6.2118 - y1_output_root_mean_squared_error: 1.7179 - y2_output_root_mean_squared_error: 2.5043 - val_loss: 8.0100 - val_y1_output_loss: 3.1563 - val_y2_output_loss: 4.7345 - val_y1_output_root_mean_squared_error: 1.7855 - val_y2_output_root_mean_squared_error: 2.1959
# Epoch 43/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.5940 - y1_output_loss: 2.5935 - y2_output_loss: 4.9565 - y1_output_root_mean_squared_error: 1.6137 - y2_output_root_mean_squared_error: 2.2338 - val_loss: 17.5808 - val_y1_output_loss: 4.8562 - val_y2_output_loss: 12.8596 - val_y1_output_root_mean_squared_error: 2.1665 - val_y2_output_root_mean_squared_error: 3.5899
# Epoch 44/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.2388 - y1_output_loss: 2.5708 - y2_output_loss: 5.6607 - y1_output_root_mean_squared_error: 1.6071 - y2_output_root_mean_squared_error: 2.3782 - val_loss: 8.2524 - val_y1_output_loss: 3.6201 - val_y2_output_loss: 4.8136 - val_y1_output_root_mean_squared_error: 1.8703 - val_y2_output_root_mean_squared_error: 2.1805
# Epoch 45/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.8722 - y1_output_loss: 2.5324 - y2_output_loss: 4.3838 - y1_output_root_mean_squared_error: 1.5824 - y2_output_root_mean_squared_error: 2.0900 - val_loss: 6.9634 - val_y1_output_loss: 2.6371 - val_y2_output_loss: 4.4389 - val_y1_output_root_mean_squared_error: 1.5891 - val_y2_output_root_mean_squared_error: 2.1067
# Epoch 46/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.3289 - y1_output_loss: 2.8576 - y2_output_loss: 6.4165 - y1_output_root_mean_squared_error: 1.6890 - y2_output_root_mean_squared_error: 2.5448 - val_loss: 8.3220 - val_y1_output_loss: 2.6415 - val_y2_output_loss: 5.9499 - val_y1_output_root_mean_squared_error: 1.5634 - val_y2_output_root_mean_squared_error: 2.4244
# Epoch 47/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.4783 - y1_output_loss: 2.1820 - y2_output_loss: 4.2534 - y1_output_root_mean_squared_error: 1.4811 - y2_output_root_mean_squared_error: 2.0699 - val_loss: 7.8531 - val_y1_output_loss: 2.9215 - val_y2_output_loss: 4.9701 - val_y1_output_root_mean_squared_error: 1.6921 - val_y2_output_root_mean_squared_error: 2.2338
# Epoch 48/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.2161 - y1_output_loss: 2.6388 - y2_output_loss: 5.5261 - y1_output_root_mean_squared_error: 1.6278 - y2_output_root_mean_squared_error: 2.3593 - val_loss: 10.3848 - val_y1_output_loss: 2.9247 - val_y2_output_loss: 7.7553 - val_y1_output_root_mean_squared_error: 1.6464 - val_y2_output_root_mean_squared_error: 2.7702
# Epoch 49/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.8555 - y1_output_loss: 2.5189 - y2_output_loss: 5.3477 - y1_output_root_mean_squared_error: 1.5816 - y2_output_root_mean_squared_error: 2.3138 - val_loss: 7.8616 - val_y1_output_loss: 2.8618 - val_y2_output_loss: 5.2624 - val_y1_output_root_mean_squared_error: 1.6341 - val_y2_output_root_mean_squared_error: 2.2785
# Epoch 50/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.7473 - y1_output_loss: 2.4079 - y2_output_loss: 5.3240 - y1_output_root_mean_squared_error: 1.5523 - y2_output_root_mean_squared_error: 2.3103 - val_loss: 7.4307 - val_y1_output_loss: 2.6178 - val_y2_output_loss: 5.0519 - val_y1_output_root_mean_squared_error: 1.5673 - val_y2_output_root_mean_squared_error: 2.2303
# Epoch 51/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.0290 - y1_output_loss: 2.3333 - y2_output_loss: 4.6885 - y1_output_root_mean_squared_error: 1.5297 - y2_output_root_mean_squared_error: 2.1654 - val_loss: 19.1917 - val_y1_output_loss: 4.6776 - val_y2_output_loss: 14.2785 - val_y1_output_root_mean_squared_error: 2.1693 - val_y2_output_root_mean_squared_error: 3.8060
# Epoch 52/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.5766 - y1_output_loss: 2.3051 - y2_output_loss: 5.2797 - y1_output_root_mean_squared_error: 1.5151 - y2_output_root_mean_squared_error: 2.2981 - val_loss: 10.3361 - val_y1_output_loss: 3.1316 - val_y2_output_loss: 7.2805 - val_y1_output_root_mean_squared_error: 1.7349 - val_y2_output_root_mean_squared_error: 2.7067
# Epoch 53/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.0846 - y1_output_loss: 2.0119 - y2_output_loss: 4.0829 - y1_output_root_mean_squared_error: 1.4066 - y2_output_root_mean_squared_error: 2.0263 - val_loss: 8.2455 - val_y1_output_loss: 3.0877 - val_y2_output_loss: 4.9055 - val_y1_output_root_mean_squared_error: 1.7831 - val_y2_output_root_mean_squared_error: 2.2508
# Epoch 54/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.6131 - y1_output_loss: 2.4378 - y2_output_loss: 5.1175 - y1_output_root_mean_squared_error: 1.5661 - y2_output_root_mean_squared_error: 2.2716 - val_loss: 8.0118 - val_y1_output_loss: 2.7623 - val_y2_output_loss: 5.5259 - val_y1_output_root_mean_squared_error: 1.5955 - val_y2_output_root_mean_squared_error: 2.3380
# Epoch 55/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.6335 - y1_output_loss: 2.0926 - y2_output_loss: 4.4883 - y1_output_root_mean_squared_error: 1.4527 - y2_output_root_mean_squared_error: 2.1268 - val_loss: 9.3711 - val_y1_output_loss: 2.8377 - val_y2_output_loss: 6.8030 - val_y1_output_root_mean_squared_error: 1.6273 - val_y2_output_root_mean_squared_error: 2.5929
# Epoch 56/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.3785 - y1_output_loss: 2.3048 - y2_output_loss: 5.0338 - y1_output_root_mean_squared_error: 1.5206 - y2_output_root_mean_squared_error: 2.2508 - val_loss: 6.7263 - val_y1_output_loss: 2.2941 - val_y2_output_loss: 4.3141 - val_y1_output_root_mean_squared_error: 1.5202 - val_y2_output_root_mean_squared_error: 2.1013
# Epoch 57/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.7166 - y1_output_loss: 2.0128 - y2_output_loss: 4.6598 - y1_output_root_mean_squared_error: 1.4236 - y2_output_root_mean_squared_error: 2.1656 - val_loss: 10.3135 - val_y1_output_loss: 2.9201 - val_y2_output_loss: 7.9084 - val_y1_output_root_mean_squared_error: 1.6143 - val_y2_output_root_mean_squared_error: 2.7763
# Epoch 58/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.0840 - y1_output_loss: 1.8232 - y2_output_loss: 4.2278 - y1_output_root_mean_squared_error: 1.3525 - y2_output_root_mean_squared_error: 2.0627 - val_loss: 7.7406 - val_y1_output_loss: 1.9459 - val_y2_output_loss: 5.8522 - val_y1_output_root_mean_squared_error: 1.3671 - val_y2_output_root_mean_squared_error: 2.4231
# Epoch 59/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.2090 - y1_output_loss: 2.2294 - y2_output_loss: 5.0149 - y1_output_root_mean_squared_error: 1.4875 - y2_output_root_mean_squared_error: 2.2353 - val_loss: 24.4767 - val_y1_output_loss: 5.7696 - val_y2_output_loss: 19.4377 - val_y1_output_root_mean_squared_error: 2.3119 - val_y2_output_root_mean_squared_error: 4.3740
# Epoch 60/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.4176 - y1_output_loss: 1.8264 - y2_output_loss: 4.5438 - y1_output_root_mean_squared_error: 1.3565 - y2_output_root_mean_squared_error: 2.1395 - val_loss: 6.0200 - val_y1_output_loss: 2.0783 - val_y2_output_loss: 4.0596 - val_y1_output_root_mean_squared_error: 1.3977 - val_y2_output_root_mean_squared_error: 2.0166
# Epoch 61/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.2967 - y1_output_loss: 1.9393 - y2_output_loss: 4.3419 - y1_output_root_mean_squared_error: 1.3981 - y2_output_root_mean_squared_error: 2.0837 - val_loss: 12.7243 - val_y1_output_loss: 2.4038 - val_y2_output_loss: 10.3302 - val_y1_output_root_mean_squared_error: 1.5379 - val_y2_output_root_mean_squared_error: 3.2185
# Epoch 62/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.1055 - y1_output_loss: 1.6764 - y2_output_loss: 3.4020 - y1_output_root_mean_squared_error: 1.2929 - y2_output_root_mean_squared_error: 1.8531 - val_loss: 5.6951 - val_y1_output_loss: 1.9673 - val_y2_output_loss: 3.9507 - val_y1_output_root_mean_squared_error: 1.3353 - val_y2_output_root_mean_squared_error: 1.9779
# Epoch 63/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.3804 - y1_output_loss: 1.6057 - y2_output_loss: 3.7899 - y1_output_root_mean_squared_error: 1.2628 - y2_output_root_mean_squared_error: 1.9457 - val_loss: 5.4234 - val_y1_output_loss: 2.0612 - val_y2_output_loss: 3.4248 - val_y1_output_root_mean_squared_error: 1.3969 - val_y2_output_root_mean_squared_error: 1.8633
# Epoch 64/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.8775 - y1_output_loss: 1.5982 - y2_output_loss: 3.2646 - y1_output_root_mean_squared_error: 1.2686 - y2_output_root_mean_squared_error: 1.8078 - val_loss: 5.9141 - val_y1_output_loss: 1.8409 - val_y2_output_loss: 4.2851 - val_y1_output_root_mean_squared_error: 1.3013 - val_y2_output_root_mean_squared_error: 2.0545
# Epoch 65/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.3530 - y1_output_loss: 1.6015 - y2_output_loss: 3.7470 - y1_output_root_mean_squared_error: 1.2621 - y2_output_root_mean_squared_error: 1.9391 - val_loss: 7.7713 - val_y1_output_loss: 2.8148 - val_y2_output_loss: 4.7881 - val_y1_output_root_mean_squared_error: 1.6944 - val_y2_output_root_mean_squared_error: 2.2137
# Epoch 66/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.4632 - y1_output_loss: 1.5677 - y2_output_loss: 3.8832 - y1_output_root_mean_squared_error: 1.2478 - y2_output_root_mean_squared_error: 1.9764 - val_loss: 5.6267 - val_y1_output_loss: 2.0967 - val_y2_output_loss: 3.8695 - val_y1_output_root_mean_squared_error: 1.3587 - val_y2_output_root_mean_squared_error: 1.9444
# Epoch 67/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.0143 - y1_output_loss: 1.4619 - y2_output_loss: 3.5340 - y1_output_root_mean_squared_error: 1.2098 - y2_output_root_mean_squared_error: 1.8843 - val_loss: 5.4981 - val_y1_output_loss: 2.2916 - val_y2_output_loss: 3.3148 - val_y1_output_root_mean_squared_error: 1.4871 - val_y2_output_root_mean_squared_error: 1.8129
# Epoch 68/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.5982 - y1_output_loss: 1.5264 - y2_output_loss: 4.1894 - y1_output_root_mean_squared_error: 1.2212 - y2_output_root_mean_squared_error: 2.0266 - val_loss: 46.0724 - val_y1_output_loss: 12.9850 - val_y2_output_loss: 32.2152 - val_y1_output_root_mean_squared_error: 3.6382 - val_y2_output_root_mean_squared_error: 5.7303
# Epoch 69/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.6490 - y1_output_loss: 1.6674 - y2_output_loss: 3.9327 - y1_output_root_mean_squared_error: 1.2964 - y2_output_root_mean_squared_error: 1.9921 - val_loss: 5.2316 - val_y1_output_loss: 1.4660 - val_y2_output_loss: 3.9301 - val_y1_output_root_mean_squared_error: 1.1602 - val_y2_output_root_mean_squared_error: 1.9712
# Epoch 70/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.4449 - y1_output_loss: 1.3317 - y2_output_loss: 3.0804 - y1_output_root_mean_squared_error: 1.1592 - y2_output_root_mean_squared_error: 1.7610 - val_loss: 5.9461 - val_y1_output_loss: 2.3807 - val_y2_output_loss: 3.5541 - val_y1_output_root_mean_squared_error: 1.5372 - val_y2_output_root_mean_squared_error: 1.8929
# Epoch 71/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.8152 - y1_output_loss: 1.4573 - y2_output_loss: 3.4124 - y1_output_root_mean_squared_error: 1.2039 - y2_output_root_mean_squared_error: 1.8346 - val_loss: 19.0543 - val_y1_output_loss: 4.0008 - val_y2_output_loss: 14.7964 - val_y1_output_root_mean_squared_error: 2.0097 - val_y2_output_root_mean_squared_error: 3.8750
# Epoch 72/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.0036 - y1_output_loss: 1.5650 - y2_output_loss: 3.5606 - y1_output_root_mean_squared_error: 1.2288 - y2_output_root_mean_squared_error: 1.8691 - val_loss: 7.7537 - val_y1_output_loss: 2.1011 - val_y2_output_loss: 5.4971 - val_y1_output_root_mean_squared_error: 1.4595 - val_y2_output_root_mean_squared_error: 2.3714
# Epoch 73/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.9627 - y1_output_loss: 1.4954 - y2_output_loss: 3.5270 - y1_output_root_mean_squared_error: 1.2212 - y2_output_root_mean_squared_error: 1.8631 - val_loss: 13.1282 - val_y1_output_loss: 4.8704 - val_y2_output_loss: 7.9446 - val_y1_output_root_mean_squared_error: 2.2363 - val_y2_output_root_mean_squared_error: 2.8508
# Epoch 74/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.6851 - y1_output_loss: 1.1148 - y2_output_loss: 2.5527 - y1_output_root_mean_squared_error: 1.0533 - y2_output_root_mean_squared_error: 1.6049 - val_loss: 4.2736 - val_y1_output_loss: 1.3832 - val_y2_output_loss: 2.9855 - val_y1_output_root_mean_squared_error: 1.1277 - val_y2_output_root_mean_squared_error: 1.7326
# Epoch 75/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.5715 - y1_output_loss: 1.0116 - y2_output_loss: 2.5328 - y1_output_root_mean_squared_error: 1.0084 - y2_output_root_mean_squared_error: 1.5983 - val_loss: 4.9486 - val_y1_output_loss: 1.1181 - val_y2_output_loss: 3.8633 - val_y1_output_root_mean_squared_error: 1.0270 - val_y2_output_root_mean_squared_error: 1.9733
# Epoch 76/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5328 - y1_output_loss: 1.0103 - y2_output_loss: 2.5807 - y1_output_root_mean_squared_error: 1.0083 - y2_output_root_mean_squared_error: 1.5863 - val_loss: 16.8498 - val_y1_output_loss: 3.7548 - val_y2_output_loss: 12.7551 - val_y1_output_root_mean_squared_error: 1.9469 - val_y2_output_root_mean_squared_error: 3.6138
# Epoch 77/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.1504 - y1_output_loss: 1.2022 - y2_output_loss: 2.9411 - y1_output_root_mean_squared_error: 1.0940 - y2_output_root_mean_squared_error: 1.7186 - val_loss: 9.0128 - val_y1_output_loss: 1.9593 - val_y2_output_loss: 7.0850 - val_y1_output_root_mean_squared_error: 1.3696 - val_y2_output_root_mean_squared_error: 2.6715
# Epoch 78/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4191 - y1_output_loss: 0.9375 - y2_output_loss: 2.5055 - y1_output_root_mean_squared_error: 0.9710 - y2_output_root_mean_squared_error: 1.5736 - val_loss: 20.9624 - val_y1_output_loss: 4.8083 - val_y2_output_loss: 15.8713 - val_y1_output_root_mean_squared_error: 2.2016 - val_y2_output_root_mean_squared_error: 4.0144
# Epoch 79/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.5714 - y1_output_loss: 1.9349 - y2_output_loss: 4.6273 - y1_output_root_mean_squared_error: 1.3937 - y2_output_root_mean_squared_error: 2.1515 - val_loss: 4.3510 - val_y1_output_loss: 1.2336 - val_y2_output_loss: 3.2125 - val_y1_output_root_mean_squared_error: 1.0662 - val_y2_output_root_mean_squared_error: 1.7928
# Epoch 80/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.1128 - y1_output_loss: 1.1972 - y2_output_loss: 2.8928 - y1_output_root_mean_squared_error: 1.0987 - y2_output_root_mean_squared_error: 1.7046 - val_loss: 4.6592 - val_y1_output_loss: 1.7978 - val_y2_output_loss: 2.7877 - val_y1_output_root_mean_squared_error: 1.3380 - val_y2_output_root_mean_squared_error: 1.6938
# Epoch 81/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.8137 - y1_output_loss: 2.0192 - y2_output_loss: 4.7803 - y1_output_root_mean_squared_error: 1.4233 - y2_output_root_mean_squared_error: 2.1881 - val_loss: 8.7251 - val_y1_output_loss: 2.0538 - val_y2_output_loss: 6.9078 - val_y1_output_root_mean_squared_error: 1.3500 - val_y2_output_root_mean_squared_error: 2.6273
# Epoch 82/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.8317 - y1_output_loss: 0.9216 - y2_output_loss: 2.9233 - y1_output_root_mean_squared_error: 0.9605 - y2_output_root_mean_squared_error: 1.7056 - val_loss: 5.6371 - val_y1_output_loss: 1.2134 - val_y2_output_loss: 4.4946 - val_y1_output_root_mean_squared_error: 1.0581 - val_y2_output_root_mean_squared_error: 2.1254
# Epoch 83/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.5877 - y1_output_loss: 0.9647 - y2_output_loss: 2.6030 - y1_output_root_mean_squared_error: 0.9855 - y2_output_root_mean_squared_error: 1.6175 - val_loss: 5.2548 - val_y1_output_loss: 1.5401 - val_y2_output_loss: 3.7940 - val_y1_output_root_mean_squared_error: 1.1982 - val_y2_output_root_mean_squared_error: 1.9543
# Epoch 84/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.7660 - y1_output_loss: 1.0044 - y2_output_loss: 2.7984 - y1_output_root_mean_squared_error: 1.0060 - y2_output_root_mean_squared_error: 1.6595 - val_loss: 6.2428 - val_y1_output_loss: 1.5689 - val_y2_output_loss: 4.5172 - val_y1_output_root_mean_squared_error: 1.2663 - val_y2_output_root_mean_squared_error: 2.1539
# Epoch 85/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.5811 - y1_output_loss: 0.9245 - y2_output_loss: 2.6269 - y1_output_root_mean_squared_error: 0.9650 - y2_output_root_mean_squared_error: 1.6279 - val_loss: 4.6864 - val_y1_output_loss: 1.0090 - val_y2_output_loss: 3.7953 - val_y1_output_root_mean_squared_error: 0.9440 - val_y2_output_root_mean_squared_error: 1.9481
# Epoch 86/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.4841 - y1_output_loss: 0.5858 - y2_output_loss: 1.9221 - y1_output_root_mean_squared_error: 0.7678 - y2_output_root_mean_squared_error: 1.3765 - val_loss: 3.4895 - val_y1_output_loss: 0.8648 - val_y2_output_loss: 2.5633 - val_y1_output_root_mean_squared_error: 0.9261 - val_y2_output_root_mean_squared_error: 1.6223
# Epoch 87/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.6662 - y1_output_loss: 0.6351 - y2_output_loss: 2.0831 - y1_output_root_mean_squared_error: 0.7976 - y2_output_root_mean_squared_error: 1.4248 - val_loss: 6.4150 - val_y1_output_loss: 1.8186 - val_y2_output_loss: 4.4577 - val_y1_output_root_mean_squared_error: 1.3556 - val_y2_output_root_mean_squared_error: 2.1394
# Epoch 88/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.6962 - y1_output_loss: 1.2386 - y2_output_loss: 3.4139 - y1_output_root_mean_squared_error: 1.1182 - y2_output_root_mean_squared_error: 1.8563 - val_loss: 5.3246 - val_y1_output_loss: 1.1333 - val_y2_output_loss: 4.2059 - val_y1_output_root_mean_squared_error: 1.0249 - val_y2_output_root_mean_squared_error: 2.0674
# Epoch 89/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.7553 - y1_output_loss: 0.6865 - y2_output_loss: 2.0625 - y1_output_root_mean_squared_error: 0.8295 - y2_output_root_mean_squared_error: 1.4378 - val_loss: 3.7981 - val_y1_output_loss: 1.2122 - val_y2_output_loss: 2.6148 - val_y1_output_root_mean_squared_error: 1.0700 - val_y2_output_root_mean_squared_error: 1.6289
# Epoch 90/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.5036 - y1_output_loss: 1.2359 - y2_output_loss: 3.2294 - y1_output_root_mean_squared_error: 1.1151 - y2_output_root_mean_squared_error: 1.8056 - val_loss: 3.4991 - val_y1_output_loss: 0.8192 - val_y2_output_loss: 2.6123 - val_y1_output_root_mean_squared_error: 0.8989 - val_y2_output_root_mean_squared_error: 1.6405
# Epoch 91/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.6757 - y1_output_loss: 0.8634 - y2_output_loss: 2.7980 - y1_output_root_mean_squared_error: 0.9274 - y2_output_root_mean_squared_error: 1.6780 - val_loss: 4.4236 - val_y1_output_loss: 0.8313 - val_y2_output_loss: 3.5965 - val_y1_output_root_mean_squared_error: 0.8793 - val_y2_output_root_mean_squared_error: 1.9106
# Epoch 92/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.9994 - y1_output_loss: 0.7115 - y2_output_loss: 2.4113 - y1_output_root_mean_squared_error: 0.8465 - y2_output_root_mean_squared_error: 1.5109 - val_loss: 10.6888 - val_y1_output_loss: 2.4551 - val_y2_output_loss: 8.0435 - val_y1_output_root_mean_squared_error: 1.5758 - val_y2_output_root_mean_squared_error: 2.8645
# Epoch 93/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.1056 - y1_output_loss: 0.8479 - y2_output_loss: 2.2546 - y1_output_root_mean_squared_error: 0.9153 - y2_output_root_mean_squared_error: 1.5060 - val_loss: 4.3171 - val_y1_output_loss: 1.7134 - val_y2_output_loss: 2.5642 - val_y1_output_root_mean_squared_error: 1.3016 - val_y2_output_root_mean_squared_error: 1.6196
# Epoch 94/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.8577 - y1_output_loss: 0.7258 - y2_output_loss: 2.1426 - y1_output_root_mean_squared_error: 0.8531 - y2_output_root_mean_squared_error: 1.4594 - val_loss: 16.6679 - val_y1_output_loss: 5.2577 - val_y2_output_loss: 10.9256 - val_y1_output_root_mean_squared_error: 2.3304 - val_y2_output_root_mean_squared_error: 3.3522
# Epoch 95/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.2508 - y1_output_loss: 0.7941 - y2_output_loss: 2.4460 - y1_output_root_mean_squared_error: 0.8925 - y2_output_root_mean_squared_error: 1.5666 - val_loss: 2.8602 - val_y1_output_loss: 0.6574 - val_y2_output_loss: 2.1645 - val_y1_output_root_mean_squared_error: 0.7941 - val_y2_output_root_mean_squared_error: 1.4932
# Epoch 96/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.7501 - y1_output_loss: 0.7523 - y2_output_loss: 1.9775 - y1_output_root_mean_squared_error: 0.8688 - y2_output_root_mean_squared_error: 1.4125 - val_loss: 4.5967 - val_y1_output_loss: 1.1764 - val_y2_output_loss: 3.3256 - val_y1_output_root_mean_squared_error: 1.0872 - val_y2_output_root_mean_squared_error: 1.8479
# Epoch 97/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.4397 - y1_output_loss: 0.5645 - y2_output_loss: 1.8708 - y1_output_root_mean_squared_error: 0.7533 - y2_output_root_mean_squared_error: 1.3683 - val_loss: 2.7440 - val_y1_output_loss: 0.6941 - val_y2_output_loss: 2.0184 - val_y1_output_root_mean_squared_error: 0.8214 - val_y2_output_root_mean_squared_error: 1.4385
# Epoch 98/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.7181 - y1_output_loss: 0.5805 - y2_output_loss: 2.1964 - y1_output_root_mean_squared_error: 0.7506 - y2_output_root_mean_squared_error: 1.4679 - val_loss: 7.7054 - val_y1_output_loss: 2.0072 - val_y2_output_loss: 5.6331 - val_y1_output_root_mean_squared_error: 1.3969 - val_y2_output_root_mean_squared_error: 2.3988
# Epoch 99/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.2445 - y1_output_loss: 0.5644 - y2_output_loss: 1.6733 - y1_output_root_mean_squared_error: 0.7525 - y2_output_root_mean_squared_error: 1.2955 - val_loss: 4.6935 - val_y1_output_loss: 1.6469 - val_y2_output_loss: 3.0534 - val_y1_output_root_mean_squared_error: 1.2624 - val_y2_output_root_mean_squared_error: 1.7607
# Epoch 100/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5429 - y1_output_loss: 0.5874 - y2_output_loss: 1.9496 - y1_output_root_mean_squared_error: 0.7686 - y2_output_root_mean_squared_error: 1.3972 - val_loss: 5.0741 - val_y1_output_loss: 0.6365 - val_y2_output_loss: 4.4248 - val_y1_output_root_mean_squared_error: 0.7632 - val_y2_output_root_mean_squared_error: 2.1193
# Epoch 101/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.0379 - y1_output_loss: 1.2000 - y2_output_loss: 2.8113 - y1_output_root_mean_squared_error: 1.0959 - y2_output_root_mean_squared_error: 1.6843 - val_loss: 2.4510 - val_y1_output_loss: 0.5418 - val_y2_output_loss: 1.8789 - val_y1_output_root_mean_squared_error: 0.7182 - val_y2_output_root_mean_squared_error: 1.3911
# Epoch 102/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.3427 - y1_output_loss: 0.5502 - y2_output_loss: 1.8090 - y1_output_root_mean_squared_error: 0.7423 - y2_output_root_mean_squared_error: 1.3385 - val_loss: 7.0320 - val_y1_output_loss: 1.1360 - val_y2_output_loss: 5.8866 - val_y1_output_root_mean_squared_error: 1.0449 - val_y2_output_root_mean_squared_error: 2.4373
# Epoch 103/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.6084 - y1_output_loss: 0.8010 - y2_output_loss: 2.7985 - y1_output_root_mean_squared_error: 0.8854 - y2_output_root_mean_squared_error: 1.6806 - val_loss: 3.1320 - val_y1_output_loss: 0.6543 - val_y2_output_loss: 2.4180 - val_y1_output_root_mean_squared_error: 0.7958 - val_y2_output_root_mean_squared_error: 1.5808
# Epoch 104/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.3535 - y1_output_loss: 0.5543 - y2_output_loss: 1.8314 - y1_output_root_mean_squared_error: 0.7423 - y2_output_root_mean_squared_error: 1.3425 - val_loss: 15.5438 - val_y1_output_loss: 3.7837 - val_y2_output_loss: 11.4138 - val_y1_output_root_mean_squared_error: 1.9683 - val_y2_output_root_mean_squared_error: 3.4161
# Epoch 105/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.9251 - y1_output_loss: 0.6607 - y2_output_loss: 2.2679 - y1_output_root_mean_squared_error: 0.8149 - y2_output_root_mean_squared_error: 1.5037 - val_loss: 2.6430 - val_y1_output_loss: 0.6334 - val_y2_output_loss: 1.9468 - val_y1_output_root_mean_squared_error: 0.7935 - val_y2_output_root_mean_squared_error: 1.4189
# Epoch 106/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.0235 - y1_output_loss: 0.7221 - y2_output_loss: 2.3042 - y1_output_root_mean_squared_error: 0.8524 - y2_output_root_mean_squared_error: 1.5156 - val_loss: 3.1908 - val_y1_output_loss: 0.8173 - val_y2_output_loss: 2.3483 - val_y1_output_root_mean_squared_error: 0.8928 - val_y2_output_root_mean_squared_error: 1.5471
# Epoch 107/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.2787 - y1_output_loss: 0.8132 - y2_output_loss: 2.4458 - y1_output_root_mean_squared_error: 0.9058 - y2_output_root_mean_squared_error: 1.5679 - val_loss: 2.9337 - val_y1_output_loss: 0.7003 - val_y2_output_loss: 2.1812 - val_y1_output_root_mean_squared_error: 0.8373 - val_y2_output_root_mean_squared_error: 1.4942
# Epoch 108/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.5366 - y1_output_loss: 1.0161 - y2_output_loss: 2.5129 - y1_output_root_mean_squared_error: 1.0123 - y2_output_root_mean_squared_error: 1.5849 - val_loss: 6.9597 - val_y1_output_loss: 0.6136 - val_y2_output_loss: 6.2415 - val_y1_output_root_mean_squared_error: 0.7551 - val_y2_output_root_mean_squared_error: 2.5278
# Epoch 109/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.1831 - y1_output_loss: 0.4628 - y2_output_loss: 1.7190 - y1_output_root_mean_squared_error: 0.6829 - y2_output_root_mean_squared_error: 1.3102 - val_loss: 5.9711 - val_y1_output_loss: 1.2169 - val_y2_output_loss: 4.7054 - val_y1_output_root_mean_squared_error: 1.0796 - val_y2_output_root_mean_squared_error: 2.1921
# Epoch 110/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.1171 - y1_output_loss: 0.4932 - y2_output_loss: 1.6216 - y1_output_root_mean_squared_error: 0.7013 - y2_output_root_mean_squared_error: 1.2749 - val_loss: 3.2548 - val_y1_output_loss: 0.5736 - val_y2_output_loss: 2.6179 - val_y1_output_root_mean_squared_error: 0.7395 - val_y2_output_root_mean_squared_error: 1.6456
# Epoch 111/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6851 - y1_output_loss: 0.7298 - y2_output_loss: 1.9514 - y1_output_root_mean_squared_error: 0.8570 - y2_output_root_mean_squared_error: 1.3966 - val_loss: 4.1204 - val_y1_output_loss: 1.5894 - val_y2_output_loss: 2.5344 - val_y1_output_root_mean_squared_error: 1.2418 - val_y2_output_root_mean_squared_error: 1.6057
# Epoch 112/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.3830 - y1_output_loss: 0.4828 - y2_output_loss: 1.9149 - y1_output_root_mean_squared_error: 0.6972 - y2_output_root_mean_squared_error: 1.3773 - val_loss: 5.7664 - val_y1_output_loss: 1.0525 - val_y2_output_loss: 4.7589 - val_y1_output_root_mean_squared_error: 0.9789 - val_y2_output_root_mean_squared_error: 2.1927
# Epoch 113/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.3702 - y1_output_loss: 0.5159 - y2_output_loss: 1.8588 - y1_output_root_mean_squared_error: 0.7185 - y2_output_root_mean_squared_error: 1.3616 - val_loss: 5.7697 - val_y1_output_loss: 1.0716 - val_y2_output_loss: 4.6327 - val_y1_output_root_mean_squared_error: 1.0273 - val_y2_output_root_mean_squared_error: 2.1713
# Epoch 114/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6378 - y1_output_loss: 0.7431 - y2_output_loss: 1.9042 - y1_output_root_mean_squared_error: 0.8647 - y2_output_root_mean_squared_error: 1.3748 - val_loss: 2.7791 - val_y1_output_loss: 0.5557 - val_y2_output_loss: 2.2116 - val_y1_output_root_mean_squared_error: 0.7123 - val_y2_output_root_mean_squared_error: 1.5072
# Epoch 115/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.2734 - y1_output_loss: 0.5181 - y2_output_loss: 1.7542 - y1_output_root_mean_squared_error: 0.7200 - y2_output_root_mean_squared_error: 1.3248 - val_loss: 6.9789 - val_y1_output_loss: 1.4655 - val_y2_output_loss: 5.3510 - val_y1_output_root_mean_squared_error: 1.2173 - val_y2_output_root_mean_squared_error: 2.3446
# Epoch 116/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.8964 - y1_output_loss: 0.6008 - y2_output_loss: 2.2823 - y1_output_root_mean_squared_error: 0.7770 - y2_output_root_mean_squared_error: 1.5142 - val_loss: 2.3678 - val_y1_output_loss: 0.4406 - val_y2_output_loss: 1.9319 - val_y1_output_root_mean_squared_error: 0.6291 - val_y2_output_root_mean_squared_error: 1.4043
# Epoch 117/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.0954 - y1_output_loss: 0.7840 - y2_output_loss: 2.5000 - y1_output_root_mean_squared_error: 0.8523 - y2_output_root_mean_squared_error: 1.5392 - val_loss: 25.1565 - val_y1_output_loss: 8.6355 - val_y2_output_loss: 15.8434 - val_y1_output_root_mean_squared_error: 2.9844 - val_y2_output_root_mean_squared_error: 4.0311
# Epoch 118/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.0071 - y1_output_loss: 0.9569 - y2_output_loss: 2.0465 - y1_output_root_mean_squared_error: 0.9797 - y2_output_root_mean_squared_error: 1.4309 - val_loss: 3.9872 - val_y1_output_loss: 0.8184 - val_y2_output_loss: 3.1130 - val_y1_output_root_mean_squared_error: 0.8859 - val_y2_output_root_mean_squared_error: 1.7895
# Epoch 119/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.1403 - y1_output_loss: 0.4799 - y2_output_loss: 1.6717 - y1_output_root_mean_squared_error: 0.6916 - y2_output_root_mean_squared_error: 1.2892 - val_loss: 4.1454 - val_y1_output_loss: 1.4971 - val_y2_output_loss: 2.6435 - val_y1_output_root_mean_squared_error: 1.2020 - val_y2_output_root_mean_squared_error: 1.6434
# Epoch 120/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.9842 - y1_output_loss: 0.4515 - y2_output_loss: 1.5418 - y1_output_root_mean_squared_error: 0.6677 - y2_output_root_mean_squared_error: 1.2403 - val_loss: 3.3668 - val_y1_output_loss: 1.0094 - val_y2_output_loss: 2.2646 - val_y1_output_root_mean_squared_error: 1.0154 - val_y2_output_root_mean_squared_error: 1.5284
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3448 - y1_output_loss: 0.1080 - y2_output_loss: 0.2352 - y1_output_root_mean_squared_error: 0.3293 - y2_output_root_mean_squared_error: 0.4862 - val_loss: 0.7156 - val_y1_output_loss: 0.2671 - val_y2_output_loss: 0.4691 - val_y1_output_root_mean_squared_error: 0.4831 - val_y2_output_root_mean_squared_error: 0.6944
# Epoch 462/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3116 - y1_output_loss: 0.1058 - y2_output_loss: 0.2040 - y1_output_root_mean_squared_error: 0.3262 - y2_output_root_mean_squared_error: 0.4530 - val_loss: 0.7518 - val_y1_output_loss: 0.2402 - val_y2_output_loss: 0.5331 - val_y1_output_root_mean_squared_error: 0.4483 - val_y2_output_root_mean_squared_error: 0.7422
# Epoch 463/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3066 - y1_output_loss: 0.1063 - y2_output_loss: 0.2000 - y1_output_root_mean_squared_error: 0.3269 - y2_output_root_mean_squared_error: 0.4469 - val_loss: 0.7534 - val_y1_output_loss: 0.2534 - val_y2_output_loss: 0.5204 - val_y1_output_root_mean_squared_error: 0.4635 - val_y2_output_root_mean_squared_error: 0.7339
# Epoch 464/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3598 - y1_output_loss: 0.1208 - y2_output_loss: 0.2368 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.4879 - val_loss: 0.9784 - val_y1_output_loss: 0.2381 - val_y2_output_loss: 0.7558 - val_y1_output_root_mean_squared_error: 0.4471 - val_y2_output_root_mean_squared_error: 0.8823
# Epoch 465/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3433 - y1_output_loss: 0.1109 - y2_output_loss: 0.2297 - y1_output_root_mean_squared_error: 0.3341 - y2_output_root_mean_squared_error: 0.4813 - val_loss: 0.6640 - val_y1_output_loss: 0.2114 - val_y2_output_loss: 0.4679 - val_y1_output_root_mean_squared_error: 0.4288 - val_y2_output_root_mean_squared_error: 0.6929
# Epoch 466/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3120 - y1_output_loss: 0.1037 - y2_output_loss: 0.2072 - y1_output_root_mean_squared_error: 0.3216 - y2_output_root_mean_squared_error: 0.4568 - val_loss: 0.6945 - val_y1_output_loss: 0.1935 - val_y2_output_loss: 0.5163 - val_y1_output_root_mean_squared_error: 0.4040 - val_y2_output_root_mean_squared_error: 0.7289
# Epoch 467/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3051 - y1_output_loss: 0.1053 - y2_output_loss: 0.1983 - y1_output_root_mean_squared_error: 0.3247 - y2_output_root_mean_squared_error: 0.4468 - val_loss: 0.7565 - val_y1_output_loss: 0.2680 - val_y2_output_loss: 0.5222 - val_y1_output_root_mean_squared_error: 0.4691 - val_y2_output_root_mean_squared_error: 0.7324
# Epoch 468/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3534 - y1_output_loss: 0.1146 - y2_output_loss: 0.2382 - y1_output_root_mean_squared_error: 0.3391 - y2_output_root_mean_squared_error: 0.4883 - val_loss: 0.6725 - val_y1_output_loss: 0.2257 - val_y2_output_loss: 0.4797 - val_y1_output_root_mean_squared_error: 0.4296 - val_y2_output_root_mean_squared_error: 0.6985
# Epoch 469/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4240 - y1_output_loss: 0.1196 - y2_output_loss: 0.3014 - y1_output_root_mean_squared_error: 0.3469 - y2_output_root_mean_squared_error: 0.5510 - val_loss: 0.8095 - val_y1_output_loss: 0.2487 - val_y2_output_loss: 0.5838 - val_y1_output_root_mean_squared_error: 0.4607 - val_y2_output_root_mean_squared_error: 0.7728
# Epoch 470/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.2828 - y1_output_loss: 0.0994 - y2_output_loss: 0.1810 - y1_output_root_mean_squared_error: 0.3166 - y2_output_root_mean_squared_error: 0.4273 - val_loss: 0.6495 - val_y1_output_loss: 0.2076 - val_y2_output_loss: 0.4688 - val_y1_output_root_mean_squared_error: 0.4107 - val_y2_output_root_mean_squared_error: 0.6934
# Epoch 471/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4284 - y1_output_loss: 0.1356 - y2_output_loss: 0.2906 - y1_output_root_mean_squared_error: 0.3693 - y2_output_root_mean_squared_error: 0.5403 - val_loss: 0.6551 - val_y1_output_loss: 0.2349 - val_y2_output_loss: 0.4499 - val_y1_output_root_mean_squared_error: 0.4408 - val_y2_output_root_mean_squared_error: 0.6789
# Epoch 472/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.2920 - y1_output_loss: 0.0974 - y2_output_loss: 0.1929 - y1_output_root_mean_squared_error: 0.3129 - y2_output_root_mean_squared_error: 0.4406 - val_loss: 0.7477 - val_y1_output_loss: 0.2038 - val_y2_output_loss: 0.5586 - val_y1_output_root_mean_squared_error: 0.4137 - val_y2_output_root_mean_squared_error: 0.7593
# Epoch 473/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.2875 - y1_output_loss: 0.1077 - y2_output_loss: 0.1882 - y1_output_root_mean_squared_error: 0.3235 - y2_output_root_mean_squared_error: 0.4276 - val_loss: 2.4492 - val_y1_output_loss: 0.6200 - val_y2_output_loss: 1.8696 - val_y1_output_root_mean_squared_error: 0.7553 - val_y2_output_root_mean_squared_error: 1.3706
# Epoch 474/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.3423 - y1_output_loss: 0.1155 - y2_output_loss: 0.2249 - y1_output_root_mean_squared_error: 0.3407 - y2_output_root_mean_squared_error: 0.4756 - val_loss: 0.9782 - val_y1_output_loss: 0.2466 - val_y2_output_loss: 0.7441 - val_y1_output_root_mean_squared_error: 0.4585 - val_y2_output_root_mean_squared_error: 0.8764
# Epoch 475/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3510 - y1_output_loss: 0.1111 - y2_output_loss: 0.2559 - y1_output_root_mean_squared_error: 0.3320 - y2_output_root_mean_squared_error: 0.4907 - val_loss: 2.9042 - val_y1_output_loss: 0.7102 - val_y2_output_loss: 2.2053 - val_y1_output_root_mean_squared_error: 0.8150 - val_y2_output_root_mean_squared_error: 1.4967
# Epoch 476/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4330 - y1_output_loss: 0.1239 - y2_output_loss: 0.3060 - y1_output_root_mean_squared_error: 0.3524 - y2_output_root_mean_squared_error: 0.5557 - val_loss: 0.7130 - val_y1_output_loss: 0.2564 - val_y2_output_loss: 0.4859 - val_y1_output_root_mean_squared_error: 0.4628 - val_y2_output_root_mean_squared_error: 0.7062
# Epoch 477/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4333 - y1_output_loss: 0.1345 - y2_output_loss: 0.2981 - y1_output_root_mean_squared_error: 0.3681 - y2_output_root_mean_squared_error: 0.5457 - val_loss: 0.6497 - val_y1_output_loss: 0.2198 - val_y2_output_loss: 0.4493 - val_y1_output_root_mean_squared_error: 0.4346 - val_y2_output_root_mean_squared_error: 0.6789
# Epoch 478/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3295 - y1_output_loss: 0.1069 - y2_output_loss: 0.2259 - y1_output_root_mean_squared_error: 0.3266 - y2_output_root_mean_squared_error: 0.4720 - val_loss: 1.8723 - val_y1_output_loss: 0.3402 - val_y2_output_loss: 1.5293 - val_y1_output_root_mean_squared_error: 0.5521 - val_y2_output_root_mean_squared_error: 1.2520
# Epoch 479/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3715 - y1_output_loss: 0.1127 - y2_output_loss: 0.2564 - y1_output_root_mean_squared_error: 0.3362 - y2_output_root_mean_squared_error: 0.5084 - val_loss: 0.6782 - val_y1_output_loss: 0.2334 - val_y2_output_loss: 0.4547 - val_y1_output_root_mean_squared_error: 0.4629 - val_y2_output_root_mean_squared_error: 0.6811
# Epoch 480/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3635 - y1_output_loss: 0.1188 - y2_output_loss: 0.2448 - y1_output_root_mean_squared_error: 0.3447 - y2_output_root_mean_squared_error: 0.4947 - val_loss: 1.4486 - val_y1_output_loss: 0.3088 - val_y2_output_loss: 1.1176 - val_y1_output_root_mean_squared_error: 0.5450 - val_y2_output_root_mean_squared_error: 1.0731
# Epoch 481/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3775 - y1_output_loss: 0.1221 - y2_output_loss: 0.2533 - y1_output_root_mean_squared_error: 0.3504 - y2_output_root_mean_squared_error: 0.5047 - val_loss: 0.9111 - val_y1_output_loss: 0.2759 - val_y2_output_loss: 0.6750 - val_y1_output_root_mean_squared_error: 0.4787 - val_y2_output_root_mean_squared_error: 0.8258
# Epoch 482/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.2845 - y1_output_loss: 0.1038 - y2_output_loss: 0.1791 - y1_output_root_mean_squared_error: 0.3224 - y2_output_root_mean_squared_error: 0.4250 - val_loss: 0.6357 - val_y1_output_loss: 0.1990 - val_y2_output_loss: 0.4527 - val_y1_output_root_mean_squared_error: 0.4140 - val_y2_output_root_mean_squared_error: 0.6814
# Epoch 483/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.2602 - y1_output_loss: 0.0959 - y2_output_loss: 0.1637 - y1_output_root_mean_squared_error: 0.3097 - y2_output_root_mean_squared_error: 0.4053 - val_loss: 0.9672 - val_y1_output_loss: 0.3375 - val_y2_output_loss: 0.6581 - val_y1_output_root_mean_squared_error: 0.5475 - val_y2_output_root_mean_squared_error: 0.8170
# Epoch 484/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.2820 - y1_output_loss: 0.0993 - y2_output_loss: 0.1804 - y1_output_root_mean_squared_error: 0.3165 - y2_output_root_mean_squared_error: 0.4264 - val_loss: 0.8389 - val_y1_output_loss: 0.2171 - val_y2_output_loss: 0.6346 - val_y1_output_root_mean_squared_error: 0.4268 - val_y2_output_root_mean_squared_error: 0.8104
# Epoch 485/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.2886 - y1_output_loss: 0.0934 - y2_output_loss: 0.1938 - y1_output_root_mean_squared_error: 0.3066 - y2_output_root_mean_squared_error: 0.4412 - val_loss: 0.6450 - val_y1_output_loss: 0.2094 - val_y2_output_loss: 0.4727 - val_y1_output_root_mean_squared_error: 0.4145 - val_y2_output_root_mean_squared_error: 0.6879
# Epoch 486/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3036 - y1_output_loss: 0.1023 - y2_output_loss: 0.2018 - y1_output_root_mean_squared_error: 0.3210 - y2_output_root_mean_squared_error: 0.4478 - val_loss: 1.0050 - val_y1_output_loss: 0.2324 - val_y2_output_loss: 0.7883 - val_y1_output_root_mean_squared_error: 0.4443 - val_y2_output_root_mean_squared_error: 0.8987
# Epoch 487/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.2806 - y1_output_loss: 0.1123 - y2_output_loss: 0.1705 - y1_output_root_mean_squared_error: 0.3328 - y2_output_root_mean_squared_error: 0.4121 - val_loss: 1.1637 - val_y1_output_loss: 0.4277 - val_y2_output_loss: 0.7627 - val_y1_output_root_mean_squared_error: 0.6216 - val_y2_output_root_mean_squared_error: 0.8817
# Epoch 488/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3798 - y1_output_loss: 0.1265 - y2_output_loss: 0.2524 - y1_output_root_mean_squared_error: 0.3572 - y2_output_root_mean_squared_error: 0.5022 - val_loss: 0.8182 - val_y1_output_loss: 0.2960 - val_y2_output_loss: 0.5610 - val_y1_output_root_mean_squared_error: 0.5015 - val_y2_output_root_mean_squared_error: 0.7527
# Epoch 489/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.2488 - y1_output_loss: 0.0926 - y2_output_loss: 0.1547 - y1_output_root_mean_squared_error: 0.3054 - y2_output_root_mean_squared_error: 0.3944 - val_loss: 0.7297 - val_y1_output_loss: 0.1896 - val_y2_output_loss: 0.5437 - val_y1_output_root_mean_squared_error: 0.4100 - val_y2_output_root_mean_squared_error: 0.7494
# Epoch 490/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.2572 - y1_output_loss: 0.0925 - y2_output_loss: 0.1676 - y1_output_root_mean_squared_error: 0.3042 - y2_output_root_mean_squared_error: 0.4057 - val_loss: 1.2150 - val_y1_output_loss: 0.2084 - val_y2_output_loss: 1.0092 - val_y1_output_root_mean_squared_error: 0.4269 - val_y2_output_root_mean_squared_error: 1.0163
# Epoch 491/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3672 - y1_output_loss: 0.1097 - y2_output_loss: 0.2599 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.5081 - val_loss: 0.6543 - val_y1_output_loss: 0.2241 - val_y2_output_loss: 0.4438 - val_y1_output_root_mean_squared_error: 0.4447 - val_y2_output_root_mean_squared_error: 0.6757
# Epoch 492/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.2951 - y1_output_loss: 0.1043 - y2_output_loss: 0.1897 - y1_output_root_mean_squared_error: 0.3222 - y2_output_root_mean_squared_error: 0.4374 - val_loss: 0.8215 - val_y1_output_loss: 0.2368 - val_y2_output_loss: 0.5962 - val_y1_output_root_mean_squared_error: 0.4569 - val_y2_output_root_mean_squared_error: 0.7828
# Epoch 493/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.2594 - y1_output_loss: 0.1018 - y2_output_loss: 0.1555 - y1_output_root_mean_squared_error: 0.3204 - y2_output_root_mean_squared_error: 0.3959 - val_loss: 0.7354 - val_y1_output_loss: 0.2277 - val_y2_output_loss: 0.5237 - val_y1_output_root_mean_squared_error: 0.4429 - val_y2_output_root_mean_squared_error: 0.7344
# Epoch 494/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3641 - y1_output_loss: 0.1150 - y2_output_loss: 0.2481 - y1_output_root_mean_squared_error: 0.3394 - y2_output_root_mean_squared_error: 0.4989 - val_loss: 0.6866 - val_y1_output_loss: 0.1914 - val_y2_output_loss: 0.5094 - val_y1_output_root_mean_squared_error: 0.4007 - val_y2_output_root_mean_squared_error: 0.7253
# Epoch 495/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3956 - y1_output_loss: 0.1107 - y2_output_loss: 0.2822 - y1_output_root_mean_squared_error: 0.3338 - y2_output_root_mean_squared_error: 0.5331 - val_loss: 0.6726 - val_y1_output_loss: 0.2135 - val_y2_output_loss: 0.4849 - val_y1_output_root_mean_squared_error: 0.4207 - val_y2_output_root_mean_squared_error: 0.7040
# Epoch 496/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.2625 - y1_output_loss: 0.1013 - y2_output_loss: 0.1639 - y1_output_root_mean_squared_error: 0.3154 - y2_output_root_mean_squared_error: 0.4038 - val_loss: 1.2571 - val_y1_output_loss: 0.5150 - val_y2_output_loss: 0.7654 - val_y1_output_root_mean_squared_error: 0.6885 - val_y2_output_root_mean_squared_error: 0.8849
# Epoch 497/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2647 - y1_output_loss: 0.1016 - y2_output_loss: 0.1645 - y1_output_root_mean_squared_error: 0.3202 - y2_output_root_mean_squared_error: 0.4027 - val_loss: 1.5294 - val_y1_output_loss: 0.3338 - val_y2_output_loss: 1.2330 - val_y1_output_root_mean_squared_error: 0.5374 - val_y2_output_root_mean_squared_error: 1.1138
# Epoch 498/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4178 - y1_output_loss: 0.1136 - y2_output_loss: 0.3024 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.5513 - val_loss: 0.5877 - val_y1_output_loss: 0.2041 - val_y2_output_loss: 0.3978 - val_y1_output_root_mean_squared_error: 0.4201 - val_y2_output_root_mean_squared_error: 0.6413
# Epoch 499/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3067 - y1_output_loss: 0.0999 - y2_output_loss: 0.2077 - y1_output_root_mean_squared_error: 0.3169 - y2_output_root_mean_squared_error: 0.4542 - val_loss: 1.1053 - val_y1_output_loss: 0.2405 - val_y2_output_loss: 0.8966 - val_y1_output_root_mean_squared_error: 0.4576 - val_y2_output_root_mean_squared_error: 0.9465
# Epoch 500/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.2915 - y1_output_loss: 0.1059 - y2_output_loss: 0.2007 - y1_output_root_mean_squared_error: 0.3234 - y2_output_root_mean_squared_error: 0.4323 - val_loss: 3.4308 - val_y1_output_loss: 0.5009 - val_y2_output_loss: 2.9140 - val_y1_output_root_mean_squared_error: 0.7005 - val_y2_output_root_mean_squared_error: 1.7147

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 33us/sample - loss: 3.4308 - y1_output_loss: 0.4918 - y2_output_loss: 2.9379 - y1_output_root_mean_squared_error: 0.7005 - y2_output_root_mean_squared_error: 1.7147
# Loss = 3.4307599191541795, Y1_loss = 0.49181652069091797, Y1_mse = 0.7005056142807007, Y2_loss = 2.9378578662872314, Y2_mse = 1.7146579027175903

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
